# %% [markdown]
# # Environment Setup Notebook
#
# This notebook helps you verify your Python environment and install any required packages for running the compactor fill-level inference demo and analysis notebooks.

# %% [markdown]
# ## 1. Check Python Version
#
# Ensure you are running Python 3.8 or newer.

# %%
import sys
print(sys.version)
# Out:
# 3.14.5 (main, May 10 2026, 10:21:34) [Clang 21.0.0 (clang-2100.0.123.102)]

# %% [markdown]
# ## 2. Install Required Packages
#
# This repository is designed to run with Python standard library only. If you want to use plotting or pandas for analysis, install them below.

# %%
# Uncomment and run if you want pandas/matplotlib for analysis
# %pip install pandas matplotlib

# %% [markdown]
# ## 3. Import Libraries
#
# Import the libraries you plan to use for analysis or plotting.

# %%
# Standard library imports (always available)
import sys
import json
from pathlib import Path

# Optional analysis/plotting imports
try:
    import pandas as pd
    import matplotlib.pyplot as plt
except ImportError:
    print("pandas/matplotlib not installed; install if you want to use them.")
# Out:
# pandas/matplotlib not installed; install if you want to use them.

# %% [markdown]
# ## 4. Verify Package Installation
#
# Run a simple test to confirm that the installed packages are working as expected.

# %%
# Test: Print Python version and (if installed) pandas version
print(f"Python version: {sys.version}")
try:
    import pandas as pd
    print(f"pandas version: {pd.__version__}")
except ImportError:
    print("pandas not installed.")
# Out:
# Python version: 3.14.5 (main, May 10 2026, 10:21:34) [Clang 21.0.0 (clang-2100.0.123.102)]
# pandas not installed.
